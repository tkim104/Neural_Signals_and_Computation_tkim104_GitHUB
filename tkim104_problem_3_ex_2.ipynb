# %% [markdown]
# # Problem 3: Drawing Regions Of Interest (ROIs)
# Given the summary images, the next step is to draw ROIs around the image to isolate the pixels belonging to a specific cell.
#
# ## Part B:
# How might you assess how good your script did?

# %% [markdown]
# One could assess how good the script did by comparing its results with some ground truths or the results of other models as well. Direct manual segmentation of regions of interest by an experienced researcher to then compare with would be the most accurate. Another way may be checking if the script could handle different types of summary images, the current script used relies on the summary image to emphasize the differences (range) of potential values as the ares for locations of interests.
