# %%
# !git clone https://github.com/tkim104/Neural_Signals_and_Computation_tkim104_GitHUB.git
# Out:
# Cloning into 'Neural_Signals_and_Computation_tkim104_GitHUB'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 21 (delta 8), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 7.52 MiB | 4.98 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
import os
os.chdir('Neural_Signals_and_Computation_tkim104_GitHUB')

# %% [markdown]
# # Problem 1: Motion correction.
# Load up the calcium image video in the file: TEST MOVIE 00001-small-motion.tif. This file represents the raw fluorescence video in TIF format, common for calcium imaging.
#
# ## Part A
# Write a script to play the data as a video (for Python users, look up the package plotly). Observe the changes in the video as a function of time and how the neuron “wiggle”.

# %%
# %run tkim104_problem_1_ex_1.ipynb
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Problem 1: Motion correction.
# Load up the calcium image video in the file: TEST MOVIE 00001-small-motion.tif. This file represents the raw fluorescence video in TIF format, common for calcium imaging.
#
# ## Part B
# Pick two frames that seem to be particularly offset from each other. Compute their correlation, and repeat for different shifts in space. Where is the correlation peak?

# %%
# %run tkim104_problem_1_ex_2.ipynb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     713             fpath = arg_lst[0]
# --> 714             filename = file_finder(fpath)
#     715         except IndexError:
#
# /usr/local/lib/python3.10/dist-packages/IPython/utils/path.py in get_py_filename(name, force_win32)
#     108     else:
# --> 109         raise IOError('File `%r` not found.' % name)
#     110
#
# OSError: File `'tkim104_problem_1_ex_2.ipynb.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-36-d08fbaf3c41c> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('run', 'tkim104_problem_1_ex_2.ipynb')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-52> in run(self, parameter_s, runner, file_finder)
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/execution.py in run(self, parameter_s, runner, file_finder)
#     723             if os.name == 'nt' and re.match(r"^'.*'$",fpath):
#     724                 warn('For Windows, use double quotes to wrap a filename: %run "mypath\\myfile.py"')
# --> 725             raise Exception(msg)
#     726         except TypeError:
#     727             if fpath in sys.meta_path:
#
# Exception: File `'tkim104_problem_1_ex_2.ipynb.py'` not found.
